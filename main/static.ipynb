# %%
import csv
from scipy.stats import zscore

# CSVファイルのパスを指定してください
csv_filename = 'data/20times_4points_gum/participant/kojima/face_landmarks_20241217_112044_690615.csv'

# ピーク検出のパラメータ
Z_THRESHOLD = 1.1    # Zスコアの閾値
MIN_INTERVAL = 0    # ピーク間の最小フレーム間隔

distances = []
timestamps = []
peak_timestamps = []
interval_count = 0
frame_numbers = []
flag = False

with open(csv_filename, 'r', newline='') as csvfile:
    csv_reader = csv.DictReader(csvfile)
    for row in csv_reader:
        distance = float(row['Distance'])
        timestamp = int(row['Timestamp'])
        frame_number = int(row['Frame_Count'])

        distances.append(distance)
        timestamps.append(timestamp)
        frame_numbers.append(frame_number)

        # 直近30件のデータでのピーク検出
        recent_distances = distances[-30:]
        z_scores = zscore(recent_distances)
        
        mean_distances = sum(recent_distances) / len(recent_distances)

        if interval_count > 0:
            interval_count -= 1
        elif abs(z_scores[-1]) > Z_THRESHOLD and (mean_distances < recent_distances[0] and not(flag)):
            peak_timestamps.append(timestamp)
            interval_count = MIN_INTERVAL
            flag = True
        elif abs(z_scores[-1]) > Z_THRESHOLD and (mean_distances > recent_distances[0] and flag):
            flag = False
                
total_peaks = len(peak_timestamps)

print(f'ピークの総数: {total_peaks}')
print('ピークが検出されたタイムスタンプ:')
for ts in peak_timestamps:
    print(ts)
# Out:
# ピークの総数: 22
# ピークが検出されたタイムスタンプ:
# 1523403
# 1722833
# 1955999
# 2155951
# 2422907
# 3089055
# 3825680
# 4688849
# 6557984
# 7222428
# 7288398
# 8189822
# 9921057
# 10853435
# 11753228
# 12652777
# 14353300
# 14951987
# 17051516
# 18017947
# 18818488
# 19985025

# %%
import csv
from scipy.stats import zscore

# CSVファイルのパスを指定してください
csv_filename = 'data/20times_npoints_gum/participant/yugo/face_landmarks_20241120_163658_a.csv'

# ピーク検出のパラメータ
Z_THRESHOLD = 0.8  # Zスコアの閾値
MIN_INTERVAL = 3    # ピーク間の最小フレーム間隔

distances = []
timestamps = []
peak_timestamps = []
interval_count = 0
frame_numbers = []
flag = False

with open(csv_filename, 'r', newline='') as csvfile:
    csv_reader = csv.DictReader(csvfile)
    for row in csv_reader:
        distance = float(row['Distance'])
        timestamp = int(row['Timestamp'])
        frame_number = int(row['Frame_Count'])

        distances.append(distance)
        timestamps.append(timestamp)
        frame_numbers.append(frame_number)

        # 直近30件のデータでのピーク検出
        recent_distances = distances[-30:]
        z_scores = zscore(recent_distances)
        
        mean_distances = sum(recent_distances) / len(recent_distances)

        if interval_count > 0:
            interval_count -= 1
        elif abs(z_scores[-1]) > Z_THRESHOLD and (mean_distances < recent_distances[0] and not(flag)):
            peak_timestamps.append(timestamp)
            interval_count = MIN_INTERVAL
            flag = True
        elif abs(z_scores[-1]) > Z_THRESHOLD and (mean_distances > recent_distances[0] and flag):
            flag = False
                
total_peaks = len(peak_timestamps)

print(f'ピークの総数: {total_peaks}')
print('ピークが検出されたタイムスタンプ:')
for ts in peak_timestamps:
    print(ts)
# Out:
# ピークの総数: 1
# ピークが検出されたタイムスタンプ:
# 13349827

# %%
import csv
from scipy.stats import zscore

# CSVファイルのパスを指定してください
csv_filename = 'data/20times_npoints_gum/participant/yugo/face_landmarks_20241120_163729_a.csv'

# ピーク検出のパラメータ
Z_THRESHOLD = 0.8  # Zスコアの閾値
MIN_INTERVAL = 3    # ピーク間の最小フレーム間隔

distances = []
timestamps = []
peak_timestamps = []
interval_count = 0
frame_numbers = []
flag = False

with open(csv_filename, 'r', newline='') as csvfile:
    csv_reader = csv.DictReader(csvfile)
    for row in csv_reader:
        distance = float(row['Distance'])
        timestamp = int(row['Timestamp'])
        frame_number = int(row['Frame_Count'])

        distances.append(distance)
        timestamps.append(timestamp)
        frame_numbers.append(frame_number)

        # 直近30件のデータでのピーク検出
        recent_distances = distances[-30:]
        z_scores = zscore(recent_distances)
        
        mean_distances = sum(recent_distances) / len(recent_distances)

        if interval_count > 0:
            interval_count -= 1
        elif abs(z_scores[-1]) > Z_THRESHOLD and (mean_distances < recent_distances[0] and not(flag)):
            peak_timestamps.append(timestamp)
            interval_count = MIN_INTERVAL
            flag = True
        elif abs(z_scores[-1]) > Z_THRESHOLD and (mean_distances > recent_distances[0] and flag):
            flag = False
                
total_peaks = len(peak_timestamps)

print(f'ピークの総数: {total_peaks}')
print('ピークが検出されたタイムスタンプ:')
for ts in peak_timestamps:
    print(ts)
# Out:
# ピークの総数: 23
# ピークが検出されたタイムスタンプ:
# 100473
# 1335450
# 1901392
# 2735883
# 3934230
# 4766600
# 5766711
# 6965685
# 7866072
# 8697467
# 9930316
# 10596660
# 11596889
# 12531130
# 13461454
# 14396821
# 15261265
# 16428053
# 17028070
# 18094593
# 18962383
# 19893895
# 21026622

# %%
import csv
from scipy.stats import zscore

# CSVファイルのパスを指定してください
csv_filename = 'data/20times_npoints_gum/participant/yugo/face_landmarks_20241120_163846_a.csv'

# ピーク検出のパラメータ
Z_THRESHOLD = 0.8  # Zスコアの閾値
MIN_INTERVAL = 3    # ピーク間の最小フレーム間隔

distances = []
timestamps = []
peak_timestamps = []
interval_count = 0
frame_numbers = []
flag = False

with open(csv_filename, 'r', newline='') as csvfile:
    csv_reader = csv.DictReader(csvfile)
    for row in csv_reader:
        distance = float(row['Distance'])
        timestamp = int(row['Timestamp'])
        frame_number = int(row['Frame_Count'])

        distances.append(distance)
        timestamps.append(timestamp)
        frame_numbers.append(frame_number)

        # 直近30件のデータでのピーク検出
        recent_distances = distances[-30:]
        z_scores = zscore(recent_distances)
        
        mean_distances = sum(recent_distances) / len(recent_distances)

        if interval_count > 0:
            interval_count -= 1
        elif abs(z_scores[-1]) > Z_THRESHOLD and (mean_distances < recent_distances[0] and not(flag)):
            peak_timestamps.append(timestamp)
            interval_count = MIN_INTERVAL
            flag = True
        elif abs(z_scores[-1]) > Z_THRESHOLD and (mean_distances > recent_distances[0] and flag):
            flag = False
                
total_peaks = len(peak_timestamps)

print(f'ピークの総数: {total_peaks}')
print('ピークが検出されたタイムスタンプ:')
for ts in peak_timestamps:
    print(ts)
# Out:
# ピークの総数: 21
# ピークが検出されたタイムスタンプ:
# 123192
# 1128306
# 1421777
# 2091055
# 2526578
# 2922029
# 3390443
# 3824040
# 4290725
# 4757480
# 5325478
# 5621264
# 6056553
# 6522925
# 7020888
# 7489285
# 7988766
# 8921184
# 9421266
# 9854691
# 10653376

# %%
import csv
from scipy.stats import zscore

# CSVファイルのパスを指定してください
csv_filename = 'data/20times_npoints_riceball/participant/yugo/face_landmarks_20241120_163944_a.csv'

# ピーク検出のパラメータ
Z_THRESHOLD = 0.8  # Zスコアの閾値
MIN_INTERVAL = 3    # ピーク間の最小フレーム間隔

distances = []
timestamps = []
peak_timestamps = []
interval_count = 0
frame_numbers = []
flag = False

with open(csv_filename, 'r', newline='') as csvfile:
    csv_reader = csv.DictReader(csvfile)
    for row in csv_reader:
        distance = float(row['Distance'])
        timestamp = int(row['Timestamp'])
        frame_number = int(row['Frame_Count'])

        distances.append(distance)
        timestamps.append(timestamp)
        frame_numbers.append(frame_number)

        # 直近30件のデータでのピーク検出
        recent_distances = distances[-30:]
        z_scores = zscore(recent_distances)
        
        mean_distances = sum(recent_distances) / len(recent_distances)

        if interval_count > 0:
            interval_count -= 1
        elif abs(z_scores[-1]) > Z_THRESHOLD and (mean_distances < recent_distances[0] and not(flag)):
            peak_timestamps.append(timestamp)
            interval_count = MIN_INTERVAL
            flag = True
        elif abs(z_scores[-1]) > Z_THRESHOLD and (mean_distances > recent_distances[0] and flag):
            flag = False
                
total_peaks = len(peak_timestamps)

print(f'ピークの総数: {total_peaks}')
print('ピークが検出されたタイムスタンプ:')
for ts in peak_timestamps:
    print(ts)
# Out:
# ピークの総数: 20
# ピークが検出されたタイムスタンプ:
# 130171
# 1227727
# 1863592
# 2430513
# 2893903
# 3362673
# 3862888
# 4397896
# 4829449
# 5294397
# 5795025
# 6262692
# 6729695
# 7226267
# 7694386
# 8194762
# 8693776
# 9093948
# 9626984
# 10126550
